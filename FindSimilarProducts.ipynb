# %%
# Imports PIL module 
from PIL import Image
  
# open method used to open different extension image file
im = Image.open("tshirt blue.jpg") 
  
# This method will show image in any image viewer 
im.show()

# %%
import pandas as pd

# %%
data = pd.read_csv("images.csv",sep=",")
image
data
# Out:
#                                      image  sender_id     label   kids
# 0     4285fab0-751a-4b74-8e9b-43af05deee22        124  Not sure  False
# 1     ea7b6656-3f84-4eb3-9099-23e623fc1018        148   T-Shirt  False
# 2     00627a3f-0477-401c-95eb-92642cbe078d         94  Not sure  False
# 3     ea2ffd4d-9b25-4ca8-9dc2-bd27f1cc59fa         43   T-Shirt  False
# 4     3b86d877-2b9e-4c8b-a6a2-1d87513309d0        189     Shoes  False
# ...                                    ...        ...       ...    ...
# 5398  dfd4079d-967b-4b3e-8574-fbac11b58103        204    Shorts  False
# 5399  befa14be-8140-4faf-8061-1039947e329d        204      Body   True
# 5400  5379356a-40ee-4890-b416-2336a7d84061        310    Shorts  False
# 5401  65507fb8-3456-4c15-b53e-d1b03bf71a59        204     Shoes  False
# 5402  32b99302-cec7-4dec-adfa-3d4029674209        204     Skirt  False
#
# [5403 rows x 4 columns]

# %%
! pip install DeepImageSearch -q
# Out:
#      |████████████████████████████████| 647 kB 24.9 MB/s
# ...

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
from DeepImageSearch import Index,LoadData,SearchImage

# %%
image_list = LoadData().from_folder(folder_list = ['images'])

# %%
Index(image_list).Start()
# Out:
# Metadata and Features are allready present, Do you want Extract Again? Enter yes or no
# yes
# ...
# 100%|██████████| 105/105 [01:15<00:00,  1.38it/s]
# Image Meta Information Saved: [meta-data-files/image_data_features.pkl]
# 105it [00:00, 2969.65it/s]
# Saved the Indexed File:[meta-data-files/image_features_vectors.ann]

# %%
SearchImage().get_similar_images("images/tshirt blue.jpg",number_of_images=5)
# Out:
# 1/1 [==============================] - 1s 1s/step
# {15: 'images/tshirt blue.jpg',
#  62: 'images/ezrzer.webp',
#  53: 'images/00d9cc6e-2564-4813-9d68-4bc4d562107b.jpg',
#  94: 'images/images.jpg',
#  30: 'images/0b7f4987-34e4-4c85-9f28-35e04ae78ece.jpg'}

# %%
new_path = "images/tshirt blue.jpg"

# %%
SearchImage().plot_similar_images(image_path = "images/tshirt blue.jpg")
# Out:
# 1/1 [==============================] - 1s 538ms/step
